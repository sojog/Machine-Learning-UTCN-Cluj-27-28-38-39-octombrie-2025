# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(2, 10)
x, x.shape, x.size
# Out:
# (array([2, 3, 4, 5, 6, 7, 8, 9]), (8,), 8)

# %%
x = np.arange(2, 10)
y = 2 * x + 1
y
# Out:
# array([ 5,  7,  9, 11, 13, 15, 17, 19])

# %%
plt.scatter(x, y);
plt.plot(x, y);

# %%
x = np.array([2, 3, 3, 5, 7, 7, 8.5, 9])
y = np.array([ 5,  7,  9, 11, 13, 15, 17, 19])

plt.scatter(x, y);
plt.plot(x, y);

# %%
x = np.array([2, 3, 3, 5, 7, 7, 8.5, 9])
y = np.array([ 5,  7,  9, 11, 13, 15, 17, 19])

plt.scatter(x, y);
plt.plot(x, y);

plt.plot(np.arange(2, 10), 2 * np.arange(2, 10) + 1)

# %%
x = np.array([2, 3, 3, 5, 7, 7, 8.5, 9])
y = np.array([ 5,  7,  9, 11, 13, 15, 17, 19])

plt.scatter(x, y);
plt.plot(x, y);

plt.plot(np.arange(2, 10), 2.1 * np.arange(2, 10) + 1.3)
