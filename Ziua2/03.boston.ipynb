# %% [markdown]
# # ! pip install pandas

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.read_csv("boston_data.csv")
# Out:
#       ID  indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat  \
# 0      1   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98
# 1      2   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14
# 2      4   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94
# 3      5   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7   5.33
# 4      7   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2  12.43
# ..   ...    ...   ...    ...    ...   ...     ...  ...  ...      ...    ...
# 328  500   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2  15.10
# 329  502  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0   9.67
# 330  503  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0   9.08
# 331  504  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0   5.64
# 332  506  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0   7.88
#
#      medv
# 0    24.0
# 1    21.6
# 2    33.4
# ...

# %%
df  = pd.read_csv("boston_data.csv", index_col=0)
df
# Out:
#      indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat  medv
# ID
# 1     2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98  24.0
# 2     7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14  21.6
# 4     2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94  33.4
# 5     2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7   5.33  36.2
# 7     7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2  12.43  22.9
# ..     ...   ...    ...    ...   ...     ...  ...  ...      ...    ...   ...
# 500   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2  15.10  17.5
# 502  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0   9.67  22.4
# 503  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0   9.08  20.6
# 504  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0   5.64  23.9
# 506  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0   7.88  11.9
#
# [333 rows x 11 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.keys()
# Out:
# Index(['indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio',
#        'lstat', 'medv'],
#       dtype='object')

# %%
df.head(2)
# Out:
#     indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat  medv
# ID
# 1    2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98  24.0
# 2    7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14  21.6

# %% [markdown]
# # Impartim in x/features/input si y/target/target

# %%
df.keys()
# Out:
# Index(['indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio',
#        'lstat', 'medv'],
#       dtype='object')

# %%
x = df[ [  'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio',
       'lstat' ]    ]

y = df [ [ 'medv'  ]]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.predict([ 
    [2.31,	0,	0.538,	6.575,	65.2,	4.0900,	1,	296,	15.3,	4.98]
])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[30.0877014]])

# %% [markdown]
# # Reimpartirea datelor + reantrenare

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((249, 10), (84, 10), (249, 1), (84, 1))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2) # 20% din date se duc catre date de test (x_test, y_test)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((266, 10), (67, 10), (266, 1), (67, 1))

# %%
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42) # mereu face acelasi split
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((266, 10), (67, 10), (266, 1), (67, 1))

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prezis = model.predict(x_test)
y_prezis.shape
# Out:
# (67, 1)

# %%
y_real_vs_prezis = pd.DataFrame( {"y_prezis": y_prezis.flatten(), "y_real": y_test.to_numpy().flatten() }) # ("real")
y_real_vs_prezis
# Out:
#      y_prezis  y_real
# 0   40.113331    48.8
# 1   12.537135     7.2
# 2   17.253168    18.7
# 3   18.074997    20.2
# 4   31.565374    28.7
# ..        ...     ...
# 62  19.432562    14.3
# 63   8.237780     5.0
# 64  18.295948    12.7
# 65  22.459163    25.0
# 66  38.308716    32.4
#
# [67 rows x 2 columns]

# %%
model.score(x_test, y_test)
# Out:
# 0.6711628785839081

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.6962440901359188

# %%
model.score(x_test, y_test)
# Out:
# 0.6711628785839081

# %%
model.intercept_
# Out:
# array([40.64456503])

# %%
score_dict = {}

for k in range(1, 11):
    knn_model = KNeighborsRegressor(n_neighbors=k)
    knn_model.fit(x_train, y_train)
    score = knn_model.score(x_test, y_test)
    print("K=", k, "score=", score)
    score_dict[k] = score

plt.bar(score_dict.keys(), score_dict.values());
# Out:
# K= 1 score= 0.5343811192816803
# K= 2 score= 0.6770061388965695
# K= 3 score= 0.7594318291848572
# K= 4 score= 0.6925262519669991
# K= 5 score= 0.6962440901359188
# K= 6 score= 0.6605955724624879
# K= 7 score= 0.6154031270989683
# K= 8 score= 0.5605617954695421
# K= 9 score= 0.511267122137999
# K= 10 score= 0.471320632917556
