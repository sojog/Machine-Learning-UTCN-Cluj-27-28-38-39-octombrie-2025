# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/4_categories.csv")
df
# Out:
#         coord_x     coord_y category
# 0    124.703038  350.089618        a
# 1    127.948668  417.534316        a
# 2     80.817806  395.823458        a
# 3    126.107518  383.713659        a
# 4    121.863843  355.151238        a
# ..          ...         ...      ...
# 913  597.447179   80.049176        d
# 914  552.212837   77.267115        d
# 915  582.085716   58.248150        d
# 916  581.338270   55.497262        d
# 917  581.421653  -10.807365        d
#
# [918 rows x 3 columns]

# %%
df["category"].unique()
# Out:
# array(['a', 'b', 'c', 'd'], dtype=object)

# %%
# x 
data = df[["coord_x", "coord_y"]]
# y 
target = df[["category"]]

# %%
plt.scatter(data["coord_x"], data["coord_y"])

# %%
plt.scatter(data["coord_x"], data["coord_y"], c=target["category"].map({"a":"red", "b":"blue", "c":"green", "d":"black"}))
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

# %%
plt.scatter(x_train["coord_x"], x_train["coord_y"])
plt.scatter(x_test["coord_x"], x_test["coord_y"])

# %%
tree_model = DecisionTreeClassifier()
tree_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
exported_data = export_graphviz(tree_model, feature_names=["coord_x", "coord_y"], class_names=["a", "b", "c", "d"], filled=True, rounded=True)
exported_data
# Out:
# 'digraph Tree {\nnode [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;\nedge [fontname="helvetica"] ;\n0 [label="coord_y <= 231.903\\ngini = 0.738\\nsamples = 734\\nvalue = [148, 144, 238, 204]\\nclass = c", fillcolor="#f2f9fd"] ;\n1 [label="coord_x <= 333.474\\ngini = 0.491\\nsamples = 349\\nvalue = [2.0, 144.0, 0.0, 203.0]\\nclass = d", fillcolor="#f3c6f8"] ;\n0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;\n2 [label="coord_y <= 211.813\\ngini = 0.04\\nsamples = 147\\nvalue = [2, 144, 0, 1]\\nclass = b", fillcolor="#4be63d"] ;\n1 -> 2 ;\n3 [label="coord_x <= 309.371\\ngini = 0.014\\nsamples = 145\\nvalue = [0, 144, 0, 1]\\nclass = b", fillcolor="#48e53a"] ;\n2 -> 3 ;\n4 [label="gini = 0.0\\nsamples = 141\\nvalue = [0, 141, 0, 0]\\nclass = b", fillcolor="#47e539"] ;\n3 -> 4 ;\n5 [label="coord_y <= 122.069\\ngini = 0.375\\nsamples = 4\\nvalue = [0, 3, 0, 1]\\nclass = b", fillcolor="#84ee7b"] ;\n3 -> 5 ;\n6 [label="gini = 0.0\\nsamples = 3\\nva
# ...

# %%
tree_source = graphviz.Source(exported_data)
tree_source.render("output/4Categorii", format="png")
tree_source.view()
# Out:
# 'output/4Categorii.pdf'

# %%
plt.scatter(data["coord_x"], data["coord_y"], c=target["category"].map({"a":"red", "b":"blue", "c":"green", "d":"black"}))

plt.plot ( np.arange(-50, 800)  , np.ones(850) * 231.9    )

# %%
plt.scatter(data["coord_x"], data["coord_y"], c=target["category"].map({"a":"red", "b":"blue", "c":"green", "d":"black"}))

plt.plot ( np.arange(-50, 800)  , np.ones(850) * 231.9    )


plt.plot( 333.474 * np.ones(232 + 50), np.arange(-50, 232))

# %%
plt.scatter(data["coord_x"], data["coord_y"], c=target["category"].map({"a":"red", "b":"blue", "c":"green", "d":"black"}))

plt.plot ( np.arange(-50, 800)  , np.ones(850) * 231.9)

plt.plot( 333.474 * np.ones(232 + 50), np.arange(-50, 232))


plt.plot(375.244 * np.ones(500 - 232), np.arange(232, 500))
