# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/4_categories.csv")
df
# Out:
#         coord_x     coord_y category
# 0    124.703038  350.089618        a
# 1    127.948668  417.534316        a
# 2     80.817806  395.823458        a
# 3    126.107518  383.713659        a
# 4    121.863843  355.151238        a
# ..          ...         ...      ...
# 913  597.447179   80.049176        d
# 914  552.212837   77.267115        d
# 915  582.085716   58.248150        d
# 916  581.338270   55.497262        d
# 917  581.421653  -10.807365        d
#
# [918 rows x 3 columns]

# %%
data = df[["coord_x", "coord_y"]]
target = df[["category"]]

# %%
plt.scatter(data["coord_x"], data["coord_y"]);

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=4)
model
# Out:
# KMeans(n_clusters=4)

# %%
model.fit(data)
# Out:
# KMeans(n_clusters=4)

# %%
model_colors = pd.DataFrame(model.labels_, columns=["cluster"])
model_colors["cluster"] = model_colors["cluster"].map({2:"red", 0:"blue", 1:"green", 3:"black", 4:"yellow", 5:"purple"})

# %%
plt.scatter(data["coord_x"], data["coord_y"], c=model_colors["cluster"] );

# %%
plt.scatter(data["coord_x"], data["coord_y"], c=target["category"].map({"a":"red", "b":"blue", "c":"green", "d":"black"}))
plt.show()
