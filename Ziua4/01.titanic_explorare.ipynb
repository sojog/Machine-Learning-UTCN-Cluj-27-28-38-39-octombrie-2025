# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# df_train = x_train + y_train

# %%
df_train = pd.read_csv("titanic/train.csv", index_col="PassengerId")
df_train.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
df_train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# x_test = df_test

# %%
df_test = pd.read_csv("titanic/test.csv", index_col="PassengerId")
df_test.head(2)
# Out:
#              Pclass                              Name     Sex   Age  SibSp  \
# PassengerId
# 892               3                  Kelly, Mr. James    male  34.5      0
# 893               3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#              Parch  Ticket    Fare Cabin Embarked
# PassengerId
# 892              0  330911  7.8292   NaN        Q
# 893              0  363272  7.0000   NaN        S

# %% [markdown]
# y_test = gender_submission

# %%
gender_submission = pd.read_csv("titanic/gender_submission.csv", index_col="PassengerId")
gender_submission.head(2)
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 1

# %%
df_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df_train.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train["Survived"].unique()
# Out:
# array([0, 1])

# %%
df_train["Pclass"].unique()
# Out:
# array([3, 1, 2])

# %%
df_train["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df_train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_train.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %% [markdown]
# Maparare clasica

# %%
# df_train["Gen"] = df_train["Sex"].map({"female":0, "male":1})
# df_train

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df_train["Sex"] = label_encoder.fit_transform(df_train["Sex"])
df_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# ...

# %% [markdown]
# from

# %%
df_train["Ticket"].nunique()
# Out:
# 681

# %%
df_train["Name"].nunique()
# Out:
# 891

# %%
df_train["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df_train["Embarked"].isnull().sum()
# Out:
# np.int64(2)

# %%
df_train[df_train["Embarked"].isnull()]
# Out:
#              Survived  Pclass                                       Name  Sex  \
# PassengerId
# 62                  1       1                        Icard, Miss. Amelie    0
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)    0
#
#               Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 62           38.0      0      0  113572  80.0   B28      NaN
# 830          62.0      0      0  113572  80.0   B28      NaN

# %%
df_train["Embarked"] = label_encoder.fit_transform(df_train["Embarked"])
df_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# ...

# %%
df_train["Embarked"].unique()
# Out:
# array([2, 0, 1, 3])

# %%
df_train.loc[[62, 830]]
# Out:
#              Survived  Pclass                                       Name  Sex  \
# PassengerId
# 62                  1       1                        Icard, Miss. Amelie    0
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)    0
#
#               Age  SibSp  Parch  Ticket  Fare Cabin  Embarked
# PassengerId
# 62           38.0      0      0  113572  80.0   B28         3
# 830          62.0      0      0  113572  80.0   B28         3

# %%
df_train = df_train.drop("Name", axis=1).drop("Ticket", axis=1)
df_train
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500   NaN
# 2                   1       1    0  38.0      1      0  71.2833   C85
# 3                   1       3    0  26.0      0      0   7.9250   NaN
# 4                   1       1    0  35.0      1      0  53.1000  C123
# 5                   0       3    1  35.0      0      0   8.0500   NaN
# ...               ...     ...  ...   ...    ...    ...      ...   ...
# 887                 0       2    1  27.0      0      0  13.0000   NaN
# 888                 1       1    0  19.0      0      0  30.0000   B42
# 889                 0       3    0   NaN      1      2  23.4500   NaN
# 890                 1       1    1  26.0      0      0  30.0000  C148
# 891                 0       3    1  32.0      0      0   7.7500   NaN
#
#              Embarked
# PassengerId
# 1                   2
# 2                   0
# 3                   2
# ...

# %%
df_train["Cabin"].unique(), df_train["Cabin"].nunique()
# Out:
# (array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#         'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#         'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#         'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#         'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#         'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#         'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#         'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#         'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#         'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#         'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#         'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#         'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df_train["Cabin"].isnull().sum()
# Out:
# np.int64(687)

# %%
set([ str(i)[0] for i in list(set(df_train["Cabin"]))])
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F', 'G', 'T', 'n'}

# %%
df_train["Cabin_Letter"] =  df_train["Cabin"].apply(lambda x: str(x)[0])
df_train
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500   NaN
# 2                   1       1    0  38.0      1      0  71.2833   C85
# 3                   1       3    0  26.0      0      0   7.9250   NaN
# 4                   1       1    0  35.0      1      0  53.1000  C123
# 5                   0       3    1  35.0      0      0   8.0500   NaN
# ...               ...     ...  ...   ...    ...    ...      ...   ...
# 887                 0       2    1  27.0      0      0  13.0000   NaN
# 888                 1       1    0  19.0      0      0  30.0000   B42
# 889                 0       3    0   NaN      1      2  23.4500   NaN
# 890                 1       1    1  26.0      0      0  30.0000  C148
# 891                 0       3    1  32.0      0      0   7.7500   NaN
#
#              Embarked Cabin_Letter
# PassengerId
# 1                   2            n
# ...

# %%
label_encoder = LabelEncoder()

df_train["Cabin_Letter"] = label_encoder.fit_transform(df_train["Cabin_Letter"])
df_train
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500   NaN
# 2                   1       1    0  38.0      1      0  71.2833   C85
# 3                   1       3    0  26.0      0      0   7.9250   NaN
# 4                   1       1    0  35.0      1      0  53.1000  C123
# 5                   0       3    1  35.0      0      0   8.0500   NaN
# ...               ...     ...  ...   ...    ...    ...      ...   ...
# 887                 0       2    1  27.0      0      0  13.0000   NaN
# 888                 1       1    0  19.0      0      0  30.0000   B42
# 889                 0       3    0   NaN      1      2  23.4500   NaN
# 890                 1       1    1  26.0      0      0  30.0000  C148
# 891                 0       3    1  32.0      0      0   7.7500   NaN
#
#              Embarked  Cabin_Letter
# PassengerId
# 1                   2             8
# ...

# %%
df_train.drop("Cabin", axis=1)
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500         2
# 2                   1       1    0  38.0      1      0  71.2833         0
# 3                   1       3    0  26.0      0      0   7.9250         2
# 4                   1       1    0  35.0      1      0  53.1000         2
# 5                   0       3    1  35.0      0      0   8.0500         2
# ...               ...     ...  ...   ...    ...    ...      ...       ...
# 887                 0       2    1  27.0      0      0  13.0000         2
# 888                 1       1    0  19.0      0      0  30.0000         2
# 889                 0       3    0   NaN      1      2  23.4500         2
# 890                 1       1    1  26.0      0      0  30.0000         0
# 891                 0       3    1  32.0      0      0   7.7500         1
#
#              Cabin_Letter
# PassengerId
# ...

# %%
df_train.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare    Embarked  Cabin_Letter
# count  891.000000  891.000000    891.000000
# mean    32.204208    1.538721      6.716049
# std     49.693429    0.794231      2.460739
# min      0.000000    0.000000      0.000000
# ...

# %% [markdown]
# Age, Gender, Survived

# %%
plt.scatter(df_train["Age"], df_train["Sex"], c=df_train["Survived"]);

# %%
plt.rcParamsDefault["figure.figsize"]
# Out:
# [6.4, 4.8]

# %% [markdown]
# plt.rcParamsDefault["figure.figsize"] - default este [6.4, 4.8]

# %%
type(plt.rcParamsDefault["figure.figsize"] )
# Out:
# list

# %%
plt.rcParams['figure.figsize'] = (12, 4.8) ## trebuie sa fie tuple in loc de lista

# %%
plt.scatter(df_train["Age"], df_train["Sex"], c=df_train["Survived"].map({0:"red", 1:"green"}));

# %%
df_train.keys()
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin',
#        'Embarked', 'Cabin_Letter'],
#       dtype='object')

# %%
df_train = df_train.drop('Cabin', axis=1)
df_train
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500         2
# 2                   1       1    0  38.0      1      0  71.2833         0
# 3                   1       3    0  26.0      0      0   7.9250         2
# 4                   1       1    0  35.0      1      0  53.1000         2
# 5                   0       3    1  35.0      0      0   8.0500         2
# ...               ...     ...  ...   ...    ...    ...      ...       ...
# 887                 0       2    1  27.0      0      0  13.0000         2
# 888                 1       1    0  19.0      0      0  30.0000         2
# 889                 0       3    0   NaN      1      2  23.4500         2
# 890                 1       1    1  26.0      0      0  30.0000         0
# 891                 0       3    1  32.0      0      0   7.7500         1
#
#              Cabin_Letter
# PassengerId
# ...

# %%
df_train.corr()
# Out:
#               Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived      1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# Pclass       -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# Sex          -0.543351  0.131900  1.000000  0.093254 -0.114631 -0.245489
# Age          -0.077221 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# SibSp        -0.035322  0.083081 -0.114631 -0.308247  1.000000  0.414838
# Parch         0.081629  0.018443 -0.245489 -0.189119  0.414838  1.000000
# Fare          0.257307 -0.549500 -0.182333  0.096067  0.159651  0.216225
# Embarked     -0.163517  0.157112  0.104057 -0.025252  0.066654  0.038322
# Cabin_Letter -0.301116  0.746616  0.123076 -0.267270  0.041540 -0.032548
#
#                   Fare  Embarked  Cabin_Letter
# Survived      0.257307 -0.163517     -0.301116
# Pclass       -0.549500  0.157112      0.746616
# Sex          -0.182333  0.104057      0.123076
# Age           0.096067 -0.025252     -0.267270
# ...

# %% [markdown]
# # pip install seaborn

# %%
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = [6.4, 4.8]

# %%
plt.rcParams["figure.figsize"]
# Out:
# [6.4, 4.8]

# %%
sns.heatmap(df_train.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df_train.corr(), cmap="coolwarm");

# %%
df_train.isnull().sum()
# Out:
# Survived          0
# Pclass            0
# Sex               0
# Age             177
# SibSp             0
# Parch             0
# Fare              0
# Embarked          0
# Cabin_Letter      0
# dtype: int64
